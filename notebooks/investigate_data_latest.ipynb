# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv('../data/cities.csv')
lines = pd.read_csv('../data/lines.csv')
stations = pd.read_csv('../data/stations.csv')
systems = pd.read_csv('../data/systems.csv')
station_lines = pd.read_csv('../data/station_lines.csv')
track_lines = pd.read_csv('../data/track_lines.csv')
tracks = pd.read_csv('../data/tracks.csv')

# %%
cities.head()
# Out:
#    id      name                            coords  start_year  url_name  \
# 0   5  Aberdeen                POINT(-2.15 57.15)      2017.0  aberdeen
# 1   6  Adelaide         POINT(138.6 -34.91666667)      2017.0  adelaide
# 2   7   Algiers              POINT(3 36.83333333)      2017.0   algiers
# 3   9    Ankara    POINT(32.91666667 39.91666667)      2017.0    ankara
# 4  16     Belém  POINT(-48.48333333 -1.466666667)      2017.0     belem
#
#      country country_state
# 0   Scotland           NaN
# 1  Australia           NaN
# 2    Algeria           NaN
# 3     Turkey           NaN
# 4     Brazil           NaN

# %%
lines.head()
# Out:
#     id  city_id                      name                     url_name  \
# 0   43        4                   Línea 2                   43-linea-2
# 1   75       34  Línea 3 Metro de Caracas  75-linea-3-metro-de-caracas
# 2  107      126                   Línea 1                  107-linea-1
# 3  604       74                La navette               604-la-navette
# 4   61       66        Línea 1 (Tramo 1A)                   61-linea-1
#
#      color  system_id  transport_mode_id
# 0  #ffbe2e        267                4.0
# 1     #000        119                NaN
# 2  #434343        249                NaN
# 3  #009ab9        346                NaN
# 4  #49aa43        250                NaN

# %%
stations.head()
# Out:
#      id                   name                                  geometry  \
# 0  7694       Keisei Tsudanuma  POINT(140.024812197129 35.6837744784723)
# 1  6003      Kossuth Lajos tér  POINT(19.0462376564033 47.5054880717671)
# 2  7732          Saint-Charles               POINT(5.3801556 43.3024646)
# 3  7695  Keisei Makuhari-Hongo  POINT(140.042146725175 35.6726021159981)
# 4  7726              Chartreux                POINT(5.4014815 43.309129)
#
#    buildstart  opening   closure  city_id
# 0      1921.0   1921.0  999999.0      114
# 1         0.0      0.0  999999.0       29
# 2      1973.0   1977.0  999999.0       74
# 3      1991.0   1991.0  999999.0      114
# 4      1973.0   1977.0  999999.0       74

# %%
tracks.head()
# Out:
#      id                                           geometry  buildstart  \
# 0  1911  LINESTRING(19.0817752 47.5005079,19.0817355 47...         0.0
# 1  2563  LINESTRING(16.4151057 48.1907238,16.4156455 48...         0.0
# 2  2557  LINESTRING(16.4164437 48.1839655,16.4161534 48...         0.0
# 3  2558  LINESTRING(16.4164901 48.1839473,16.416198 48....         0.0
# 4  2564  LINESTRING(16.415259 48.1908074,16.4153634 48....         0.0
#
#    opening   closure  length  city_id
# 0      0.0  999999.0    6719       29
# 1      0.0  999999.0     199      118
# 2      0.0  999999.0     925      118
# 3      0.0  999999.0     881      118
# 4      0.0  999999.0     213      118

# %%
track_lines.head()
# Out:
#      id  section_id  line_id                  created_at  \
# 0  2494        1278      343         2017-11-21 00:00:00
# 1  4124        4477      779  2017-11-21 00:09:55.135507
# 2  2495          21        9         2017-11-21 00:00:00
# 3  2496         940      228         2017-11-21 00:00:00
# 4  4129        4478      793  2017-11-21 17:44:39.765832
#
#                    updated_at  city_id
# 0         2017-11-21 00:00:00      252
# 1  2017-11-21 00:09:55.135507       63
# 2         2017-11-21 00:00:00        1
# 3         2017-11-21 00:00:00       79
# 4  2017-11-21 17:44:39.765832       48

# %%
station_lines.head()
# Out:
#    id  station_id  line_id  city_id           created_at           updated_at
# 0  47        7754      570       74  2017-11-21 00:00:00  2017-11-21 00:00:00
# 1  48        7771      571       74  2017-11-21 00:00:00  2017-11-21 00:00:00
# 2  49        7764      571       74  2017-11-21 00:00:00  2017-11-21 00:00:00
# 3  50        7763      571       74  2017-11-21 00:00:00  2017-11-21 00:00:00
# 4  51        7729      571       74  2017-11-21 00:00:00  2017-11-21 00:00:00

# %%
systems.head()
# Out:
#    id  city_id name
# 0   1        5  NaN
# 1   2        6  NaN
# 2   3        7  NaN
# 3   4        8  NaN
# 4   5        9  NaN

# %%
cities_tracks = cities.merge(tracks, how='inner', left_on='id', right_on='city_id')

# %%
cities_tracks.head()
# Out:
#    id_x     name                           coords  start_year url_name  \
# 0   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 1   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 2   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 3   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 4   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
#
#          country country_state  id_y  \
# 0  United States          Ill.  4893
# 1  United States          Ill.  4894
# 2  United States          Ill.  4896
# 3  United States          Ill.  1982
# 4  United States          Ill.  1973
#
#                                             geometry  buildstart  opening  \
# 0  LINESTRING(-87.6337015470323 41.8755914840214,...      1895.0   1895.0
# 1  LINESTRING(-87.7449583 41.8725646,-87.7548059 ...      1905.0   1905.0
# 2  LINESTRING(-87.8827459601093 41.880327150266,-...      1926.0   1926.0
# 3  LINESTRING(-87.7131606 41.9664862,-87.713166 4...         0.0   1907.0
# 4  LINESTRING(-87.6536417 41.9428291,-87.653729 4...         0.0   1907.0
#
#     closure  length  city_id
# 0    1958.0    9451      147
# 1    1958.0     818      147
# 2    1951.0    3515      147
# 3  999999.0     180      147
# 4  999999.0    5571      147

# %%
cities_tracks.drop(columns=['country_state', 'id_x'], inplace=True)
cities_tracks.rename(columns={'id_y': 'track_id'}, inplace=True)
cities_tracks.head()
# Out:
#       name                           coords  start_year url_name  \
# 0  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 1  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 2  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 3  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 4  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
#
#          country  track_id                                           geometry  \
# 0  United States      4893  LINESTRING(-87.6337015470323 41.8755914840214,...
# 1  United States      4894  LINESTRING(-87.7449583 41.8725646,-87.7548059 ...
# 2  United States      4896  LINESTRING(-87.8827459601093 41.880327150266,-...
# 3  United States      1982  LINESTRING(-87.7131606 41.9664862,-87.713166 4...
# 4  United States      1973  LINESTRING(-87.6536417 41.9428291,-87.653729 4...
#
#    buildstart  opening   closure  length  city_id
# 0      1895.0   1895.0    1958.0    9451      147
# 1      1905.0   1905.0    1958.0     818      147
# 2      1926.0   1926.0    1951.0    3515      147
# 3         0.0   1907.0  999999.0     180      147
# 4         0.0   1907.0  999999.0    5571      147

# %%
track_length = cities_tracks.groupby('country').agg({'length': 'sum'})
# Out:
#                  length
# country
# Argentina       1472481
# Australia        426050
# Austria          156087
# Bolivia           33640
# Brazil          1018246
# Canada           775250
# Chile            623819
# China           1650882
# Colombia         173514
# Czech Republic    93353
# England         2103766
# France          2043384
# Germany          162510
# Hungary           63525
# Italy            781378
# Japan           7572397
# Malaysia          86145
# Mexico           446306
# México            59450
# Peru              39004
# Portugal         116671
# Scotland         420670
# Spain           1328966
# Sweden           140571
# United States   2922264
# Venezuela          9939

# %%
cities_tracks['country'].nunique()
# Out:
# 26

# %%
fig, ax = plt.subplots(figsize=(10,10))
track_length = cities_tracks.groupby('country').agg({'length': 'sum'}).reset_index().sort_values(by='length')
x=track_length['country']
ax.bar(x, track_length['length'], color='m')
plt.setp(ax.get_xticklabels(), rotation=90, ha="center")
ax.set_title('Total Length of Track per Country')
ax.set_ylabel('Track Length(millions of km)');

fig.savefig('../images/length_track_bar.png')

# %%
track_length = cities_tracks.groupby('country').agg({'length': 'sum'}).reset_index().sort_values(by='length')
south_america = track_length[(track_length['country'] == 'Venezuela') | (track_length['country'] == 'Bolivia')
            | (track_length['country'] == 'Peru') | (track_length['country'] == 'Colombia')
            | (track_length['country'] == 'Chile') | (track_length['country'] == 'Argentina')
            | (track_length['country'] == 'Brazil')]
# [0,1,2,11, 15, 18, 20]

# %%
fig, ax = plt.subplots()

x=south_america['country']
ax.bar(x, south_america['length'], color='m')
plt.setp(ax.get_xticklabels(), rotation=90, ha="center")
ax.set_title('Total Length of Track per Country: South America')
ax.set_ylabel('Track Length(millions of km)')

fig.savefig('../images/length_track_bar_2.png');

# %%
cities_stations = cities.merge(stations, how='inner', left_on='id', right_on='city_id')
cities_stations.head()
# Out:
#    id_x   name_x                           coords  start_year url_name  \
# 0   211   Ottawa         POINT(-75.71666667 45.4)      2000.0   ottawa
# 1   211   Ottawa         POINT(-75.71666667 45.4)      2000.0   ottawa
# 2   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 3   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
# 4   147  Chicago  POINT(-87.61666667 41.83333333)      1892.0  chicago
#
#          country country_state  id_y       name_y  \
# 0         Canada          Ont.  8421      Carling
# 1         Canada          Ont.  8422      Bayview
# 2  United States          Ill.  6324       Kedzie
# 3  United States          Ill.  6317  Irving Park
# 4  United States          Ill.  6368        Grand
#
#                                     geometry  buildstart  opening   closure  \
# 0   POINT(-75.7095199715726 45.397399937456)      2000.0   2001.0  999999.0
# 1   POINT(-75.721629884714 45.4089954402401)      2000.0   2001.0  999999.0
# 2              POINT(-87.7095589 41.9661285)         0.0   1907.0  999999.0
# 3              POINT(-87.6749332 41.9543516)         0.0   1907.0  999999.0
# 4  POINT(-87.6356481487934 41.8916007945802)         0.0   1921.0    1970.0
#
#    city_id
# 0      211
# 1      211
# 2      147
# 3      147
# 4      147

# %%
cities_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15794 entries, 0 to 15793
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       15794 non-null  object
#  1   coords        15794 non-null  object
#  2   start_year    15794 non-null  float64
#  3   url_name      15794 non-null  object
#  4   country       15794 non-null  object
#  5   station_id    15794 non-null  int64
#  6   station_name  14248 non-null  object
#  7   geometry      15794 non-null  object
#  8   buildstart    14342 non-null  float64
#  9   opening       15721 non-null  float64
#  10  closure       15713 non-null  float64
#  11  city_id       15794 non-null  int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
# fig, ax = plt.subplots(figsize=(10,10))
# station_open = cities_stations.groupby(cities_stations['country'] == 'Japan').reset_index()
# x=station_open[station_open['country'] == 'Japan']
# ax.bar(x, track_length['length'], color='m')
# plt.setp(ax.get_xticklabels(), rotation=90, ha="center")
# ax.set_title('Total Length of Track per Country')
# ax.set_ylabel('Track Length(millions of km)');

# fig.savefig('../images/length_track_bar.png')

# %%
cities_stations[['country', 'opening']].groupby('country').count()
# Out:
#                 opening
# country
# Argentina           675
# Australia           109
# Austria             306
# Belgium               4
# Bolivia              42
# Brazil              353
# Canada              218
# Chile               462
# China               705
# Colombia             37
# Czech Republic       46
# England             970
# France             2757
# Germany             385
# Hungary              62
# Italy               397
# Japan              4613
# Malaysia             37
# Mexico              467
# México               20
# Netherlands           2
# Peru                 31
# Portugal             56
# Scotland            157
# Spain               775
# Sweden               25
# United States      2001
# Venezuela             9

# %%
start_ = cities_stations[['country', 'start_year']].groupby(['country', 'start_year']).count()
start_.head(50)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Argentina, 1854.0), (Australia, 1854.0), (Australia, 1858.0), (Austria, 1896.0), (Austria, 1978.0), (Austria, 2017.0), (Belgium, 2017.0), (Bolivia, 2011.0), (Brazil, 1858.0), (Brazil, 1860.0), (Brazil, 2014.0), (Canada, 1949.0), (Canada, 1966.0), (Canada, 2000.0), (Canada, 2013.0), (Chile, 1850.0), (Chile, 1855.0), (Chile, 1999.0), (China, 1965.0), (China, 1990.0), (China, 2017.0), (Colombia, 1872.0), (Czech Republic, 2017.0), (England, 1833.0), (England, 1835.0), (England, 2017.0), (France, 1862.0), (France, 1877.0), (France, 1880.0), (France, 1890.0), (France, 1897.0), (France, 1898.0), (France, 1909.0), (France, 1934.0), (France, 1991.0), (France, 1996.0), (France, 1998.0), (France, 2001.0), (France, 2002.0), (France, 2003.0), (France, 2004.0), (France, 2006.0), (France, 2007.0), (France, 2009.0), (France, 2010.0), (France, 2018.0), (Germany, 1896.0), (Germany, 2017.0), (Hungary, 2017.0), (Italy, 1840.0)]

# %%
start_ = cities_stations[['country', 'name_y', 'start_year']].groupby(['country', 'name_y', 'start_year']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Brazil'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-c19cfedec4e8> in <module>
#       1 start_ = cities_stations[['country', 'name_y', 'start_year']].groupby(['country', 'name_y', 'start_year']).count()
# ----> 2 start_['Brazil']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Brazil'

# %%
fig, ax = plt.subplots()
x = start_['start_year']
y = start_
ax.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'start_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-9e3761099e08> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 x = start_['start_year']
#       3 y = start_
#       4 ax.scatter(x, y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'start_year'
